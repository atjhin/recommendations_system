# %%
import json
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

def spotify(client_id, client_secret):
    # Authenticate
    client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
    sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
    return sp

# Set up the credentials
with open('config.json') as config_file:
    config = json.load(config_file)

client_id = config['client_id']['0']
client_secret = config['client_secret']['0']

sp = spotify(client_id, client_secret)

# %%
df = pd.read_csv("test.csv")
df
# Out:
#      Unnamed: 0         track_name  danceability  energy  key  loudness  mode  \
# 0             0        Not Like Us         0.898   0.472    1    -7.001     1
# 1             1          Like That         0.814   0.676   11    -4.670     0
# 2             2            Breathe         0.760   0.546   11   -13.092     1
# 3             3             BANDIT         0.686   0.733    2    -5.268     1
# 4             4           CARNIVAL         0.594   0.811    1    -5.746     1
# ..          ...                ...           ...     ...  ...       ...   ...
# 674         674   Sky is the Limit         0.519   0.256    4   -14.184     1
# 675         675              4EVER         0.750   0.585    9    -7.576     0
# 676         676          Liability         0.587   0.229   10   -11.254     0
# 677         677  Chinese Satellite         0.302   0.444   10    -9.948     1
# 678         678     Fourth of July         0.441   0.104    6   -22.399     0
#
#      speechiness  acousticness  instrumentalness  ...  valence    tempo  \
# 0         0.0776       0.01070          0.000000  ...    0.214  101.061
# 1         0.2310       0.00709          0.000013  ...    0.312  162.012
# 2         0.0616       0.02840          0.924000  ...    0.113  118.051
# 3         0.0576       0.00567          0.000000  ...    0.141  130.095
# 4         0.1590       0.18900          0.000000  ...    0.311  148.144
# ..           ...           ...               ...  ...      ...      ...
# 674       0.0444       0.89100          0.000000  ...    0.281  122.715
# 675       0.0285       0.04900          0.005520  ...    0.584  102.331
# 676       0.1280       0.92000          0.000000  ...    0.379   75.670
# 677       0.0453       0.75400          0.024400  ...    0.379  120.026
# 678       0.0459       0.97300          0.354000  ...    0.156  120.266
#
#                type                      id  \
# 0    audio_features  6AI3ezQ4o3HUoP6Dhudph3
# 1    audio_features  2tudvzsrR56uom6smgOcSf
# 2    audio_features  5NAOhPAZ57eFAXr3qatS6i
# 3    audio_features  3jRNIvRWw7vdtoMY2hb0Wt
# 4    audio_features  3w0w2T288dec0mgeZZqoNN
# ..              ...                     ...
# 674  audio_features  1OBK4DltPHWoeilauCyckU
# 675  audio_features  5mIOsPuQdXchVY0jB5NO9Q
# 676  audio_features  6Kkt27YmFyIFrcX3QXFi2o
# 677  audio_features  60zlkOrTCHjpRTd1g6PI5y
# 678  audio_features  4K3RZJ8sWPbv0IedcnEfw6
#
#                                       uri  \
# 0    spotify:track:6AI3ezQ4o3HUoP6Dhudph3
# 1    spotify:track:2tudvzsrR56uom6smgOcSf
# 2    spotify:track:5NAOhPAZ57eFAXr3qatS6i
# 3    spotify:track:3jRNIvRWw7vdtoMY2hb0Wt
# 4    spotify:track:3w0w2T288dec0mgeZZqoNN
# ..                                    ...
# 674  spotify:track:1OBK4DltPHWoeilauCyckU
# 675  spotify:track:5mIOsPuQdXchVY0jB5NO9Q
# 676  spotify:track:6Kkt27YmFyIFrcX3QXFi2o
# 677  spotify:track:60zlkOrTCHjpRTd1g6PI5y
# 678  spotify:track:4K3RZJ8sWPbv0IedcnEfw6
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/6AI3ezQ4o3HU...
# 1    https://api.spotify.com/v1/tracks/2tudvzsrR56u...
# 2    https://api.spotify.com/v1/tracks/5NAOhPAZ57eF...
# 3    https://api.spotify.com/v1/tracks/3jRNIvRWw7vd...
# 4    https://api.spotify.com/v1/tracks/3w0w2T288dec...
# ..                                                 ...
# 674  https://api.spotify.com/v1/tracks/1OBK4DltPHWo...
# 675  https://api.spotify.com/v1/tracks/5mIOsPuQdXch...
# 676  https://api.spotify.com/v1/tracks/6Kkt27YmFyIF...
# 677  https://api.spotify.com/v1/tracks/60zlkOrTCHjp...
# 678  https://api.spotify.com/v1/tracks/4K3RZJ8sWPbv...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/6AI3...      274192
# 1    https://api.spotify.com/v1/audio-analysis/2tud...      267707
# 2    https://api.spotify.com/v1/audio-analysis/5NAO...      170847
# 3    https://api.spotify.com/v1/audio-analysis/3jRN...      147747
# 4    https://api.spotify.com/v1/audio-analysis/3w0w...      264324
# ..                                                 ...         ...
# 674  https://api.spotify.com/v1/audio-analysis/1OBK...      159345
# 675  https://api.spotify.com/v1/audio-analysis/5mIO...      159595
# 676  https://api.spotify.com/v1/audio-analysis/6Kkt...      171728
# 677  https://api.spotify.com/v1/audio-analysis/60zl...      217070
# 678  https://api.spotify.com/v1/audio-analysis/4K3R...      279316
#
#      time_signature  genre
# 0                 4    rap
# 1                 4    rap
# 2                 4    rap
# 3                 4    rap
# 4                 4    rap
# ..              ...    ...
# 674               4   easy
# 675               4   easy
# 676               4   easy
# 677               4   easy
# 678               4   easy
#
# [679 rows x 21 columns]

# %%
drop_columns = ['Unnamed: 0', 'track_name', 'type', 'id', 'uri', 'track_href', 'analysis_url']

df_knn = df.drop(columns=drop_columns)

df_knn
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.898   0.472    1    -7.001     1       0.0776       0.01070
# 1           0.814   0.676   11    -4.670     0       0.2310       0.00709
# 2           0.760   0.546   11   -13.092     1       0.0616       0.02840
# 3           0.686   0.733    2    -5.268     1       0.0576       0.00567
# 4           0.594   0.811    1    -5.746     1       0.1590       0.18900
# ..            ...     ...  ...       ...   ...          ...           ...
# 674         0.519   0.256    4   -14.184     1       0.0444       0.89100
# 675         0.750   0.585    9    -7.576     0       0.0285       0.04900
# 676         0.587   0.229   10   -11.254     0       0.1280       0.92000
# 677         0.302   0.444   10    -9.948     1       0.0453       0.75400
# 678         0.441   0.104    6   -22.399     0       0.0459       0.97300
#
#      instrumentalness  liveness  valence    tempo  duration_ms  \
# 0            0.000000     0.141    0.214  101.061       274192
# 1            0.000013     0.119    0.312  162.012       267707
# 2            0.924000     0.103    0.113  118.051       170847
# 3            0.000000     0.246    0.141  130.095       147747
# 4            0.000000     0.339    0.311  148.144       264324
# ..                ...       ...      ...      ...          ...
# 674          0.000000     0.181    0.281  122.715       159345
# 675          0.005520     0.155    0.584  102.331       159595
# 676          0.000000     0.100    0.379   75.670       171728
# 677          0.024400     0.152    0.379  120.026       217070
# 678          0.354000     0.119    0.156  120.266       279316
#
#      time_signature genre
# 0                 4   rap
# 1                 4   rap
# 2                 4   rap
# 3                 4   rap
# 4                 4   rap
# ..              ...   ...
# 674               4  easy
# 675               4  easy
# 676               4  easy
# 677               4  easy
# 678               4  easy
#
# [679 rows x 14 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(df_knn.drop('genre', axis = 1))
# Out:
# StandardScaler()

# %%
scaled_features = scaler.transform(df_knn.drop('genre', axis = 1))

# %%
df_feat = pd.DataFrame(scaled_features, columns = df_knn.columns[:-1])
df_feat
# Out:
#      danceability    energy       key  loudness      mode  speechiness  \
# 0        1.753918  0.236163 -1.140921  0.621083  0.822522    -0.072810
# 1        1.293763  0.992448  1.711382  0.889810 -1.215772     1.742317
# 2        0.997950  0.510502  1.711382 -0.081112  0.822522    -0.262132
# 3        0.592575  1.203763 -0.855691  0.820870  0.822522    -0.309463
# 4        0.088596  1.492931 -1.140921  0.765764  0.822522     0.890367
# ..            ...       ...       ...       ...       ...          ...
# 674     -0.322256 -0.564609 -0.285230 -0.207002  0.822522    -0.465653
# 675      0.943169  0.655086  1.140921  0.554795 -1.215772    -0.653792
# 676      0.050250 -0.664705  1.426152  0.130780 -1.215772     0.523555
# 677     -1.510989  0.132359  1.426152  0.281341  0.822522    -0.455004
# 678     -0.749542 -1.128115  0.285230 -1.154061 -1.215772    -0.447905
#
#      acousticness  instrumentalness  liveness   valence     tempo  \
# 0       -1.372689         -0.491985 -0.199444 -0.663246 -0.529055
# 1       -1.382176         -0.491946 -0.387204 -0.234073  1.555544
# 2       -1.326171          2.321161 -0.523757 -1.105557  0.052024
# 3       -1.385908         -0.491985  0.696682 -0.982936  0.463944
# 4       -0.904097         -0.491985  1.490394 -0.238452  1.081242
# ..            ...               ...       ...       ...       ...
# 674      0.940836         -0.491985  0.141937 -0.369832  0.211538
# 675     -1.272032         -0.475179 -0.079961  0.957102 -0.485620
# 676      1.017051         -0.491985 -0.549360  0.059341 -1.397459
# 677      0.580785         -0.417699 -0.105564  0.059341  0.119571
# 678      1.156340          0.585779 -0.387204 -0.917247  0.127780
#
#      duration_ms  time_signature
# 0       1.204204        0.259674
# 1       1.095199        0.259674
# 2      -0.532890        0.259674
# 3      -0.921171        0.259674
# 4       1.038335        0.259674
# ..           ...             ...
# 674    -0.726224        0.259674
# 675    -0.722022        0.259674
# 676    -0.518082        0.259674
# 677     0.244058        0.259674
# 678     1.290331        0.259674
#
# [679 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X = df_feat
y = df_knn['genre']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=101)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
pred = knn.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test, pred))
# Out:
# [[33  0  0  0  0  0  0]
#  [ 0 17  5  1  8  0  2]
#  [ 0  5  6  3  3  0  4]
#  [ 0  0  0 27  1  0  0]
#  [ 0  5  0  0 20  1  0]
#  [ 0  0  0  7  2 19  5]
#  [ 0  6  3  0  4  3 14]]

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#    classical       1.00      1.00      1.00        33
#        cover       0.52      0.52      0.52        33
#         easy       0.43      0.29      0.34        21
#          edm       0.71      0.96      0.82        28
#          old       0.53      0.77      0.62        26
#          rap       0.83      0.58      0.68        33
#          rnb       0.56      0.47      0.51        30
#
#     accuracy                           0.67       204
#    macro avg       0.65      0.65      0.64       204
# weighted avg       0.67      0.67      0.66       204

# %%
error_rate = []

for i in range(1, 40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40), error_rate, color = 'blue', linestyle = '--', marker = 'o', markerfacecolor = 'red', markersize = 10 )
plt.title('Error rate vs K')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
knn = KNeighborsClassifier(n_neighbors=14)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=14)

# %%
pred = knn.predict(X_test)

# %%
print(confusion_matrix(y_test, pred))
# Out:
# [[33  0  0  0  0  0  0]
#  [ 0 25  3  0  4  1  0]
#  [ 0  6 10  1  1  0  3]
#  [ 0  0  1 27  0  0  0]
#  [ 0  9  2  0 14  1  0]
#  [ 0  0  1  5  0 22  5]
#  [ 0  1  8  1  1  2 17]]

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#    classical       1.00      1.00      1.00        33
#        cover       0.61      0.76      0.68        33
#         easy       0.40      0.48      0.43        21
#          edm       0.79      0.96      0.87        28
#          old       0.70      0.54      0.61        26
#          rap       0.85      0.67      0.75        33
#          rnb       0.68      0.57      0.62        30
#
#     accuracy                           0.73       204
#    macro avg       0.72      0.71      0.71       204
# weighted avg       0.74      0.73      0.72       204
