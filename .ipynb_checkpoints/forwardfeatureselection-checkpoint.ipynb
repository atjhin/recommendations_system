# %%
import json
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import warnings

# Suppress the specific FutureWarning related to fit_params
warnings.filterwarnings(action='ignore', category=FutureWarning, module='sklearn.model_selection._validation')

from sklearn.feature_selection import SequentialFeatureSelector
from mlxtend.feature_selection import SequentialFeatureSelector as SFS


def spotify(client_id, client_secret):
    # Authenticate
    client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
    sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
    return sp

# Set up the credentials
with open('config.json') as config_file:
    config = json.load(config_file)

client_id = config['client_id']['0']
client_secret = config['client_secret']['0']

sp = spotify(client_id, client_secret)

# %%
df = pd.read_csv("my_songs.csv")
df
# Out:
#      Unnamed: 0  playlist                      id  \
# 0             0  Its time  2FoahzOSxJnalPA8aBUme3
# 1             1  Its time  6x9pCndnXEoea0CMcfjs9W
# 2             2  Its time  2FDTHlrBguDzQkp7PVj16Q
# 3             3  Its time  5KI7I4mEtulXcv5VQJaV35
# 4             4  Its time  4yLyVdEqV790aIXyGif85v
# ..          ...       ...                     ...
# 284         284       Old  6crfO56bDm0RjpctUuGs5X
# 285         285       Old  4l9hml2UCnxoNI3yCdL1BW
# 286         286       Old  7Kqk5EpwqiukPkDutSFFZk
# 287         287       Old  1sJnKCMOkGvcRPes8Tln2x
# 288         288       Old  4m6OC8u2rC6LMFtFWsME7d
#
#                                 name genre  danceability   energy  key  \
# 0                          all of me   Rap         0.652  0.80600    5
# 1                           n.h.i.e.   Rap         0.818  0.51200    5
# 2                           Sprinter   Rap         0.918  0.68100    1
# 3                       just like me   Rap         0.701  0.65300    1
# 4                            red sky   Rap         0.474  0.62100    7
# ..                               ...   ...           ...      ...  ...
# 284         I'm In The Mood For Love   Old         0.580  0.05450    9
# 285               My Funny Valentine   Old         0.438  0.00756    0
# 286                   Did I Remember   Old         0.677  0.26400    8
# 287                 My Kind of Night   Old         0.840  0.17800   10
# 288  Time After Time - Vocal Version   Old         0.501  0.04540    0
#
#      loudness  mode  ...  instrumentalness  liveness  valence    tempo  \
# 0      -5.707     0  ...          0.000011    0.8420    0.779  159.947
# 1      -9.056     0  ...          0.037100    0.1100    0.153  131.974
# 2      -4.705     1  ...          0.000000    0.0615    0.706  139.057
# 3      -4.695     1  ...          0.000028    0.3060    0.505   82.984
# 4      -8.253     0  ...          0.000000    0.1600    0.396  114.314
# ..        ...   ...  ...               ...       ...      ...      ...
# 284   -14.594     0  ...          0.000265    0.0967    0.177  123.341
# 285   -26.440     0  ...          0.006430    0.1090    0.277  133.320
# 286    -9.111     1  ...          0.006010    0.0825    0.438  120.974
# 287   -11.133     1  ...          0.000000    0.1130    0.529  114.412
# 288   -18.783     1  ...          0.000038    0.2000    0.255   99.783
#
#                type                                   uri  \
# 0    audio_features  spotify:track:2FoahzOSxJnalPA8aBUme3
# 1    audio_features  spotify:track:6x9pCndnXEoea0CMcfjs9W
# 2    audio_features  spotify:track:2FDTHlrBguDzQkp7PVj16Q
# 3    audio_features  spotify:track:5KI7I4mEtulXcv5VQJaV35
# 4    audio_features  spotify:track:4yLyVdEqV790aIXyGif85v
# ..              ...                                   ...
# 284  audio_features  spotify:track:6crfO56bDm0RjpctUuGs5X
# 285  audio_features  spotify:track:4l9hml2UCnxoNI3yCdL1BW
# 286  audio_features  spotify:track:7Kqk5EpwqiukPkDutSFFZk
# 287  audio_features  spotify:track:1sJnKCMOkGvcRPes8Tln2x
# 288  audio_features  spotify:track:4m6OC8u2rC6LMFtFWsME7d
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/2FoahzOSxJna...
# 1    https://api.spotify.com/v1/tracks/6x9pCndnXEoe...
# 2    https://api.spotify.com/v1/tracks/2FDTHlrBguDz...
# 3    https://api.spotify.com/v1/tracks/5KI7I4mEtulX...
# 4    https://api.spotify.com/v1/tracks/4yLyVdEqV790...
# ..                                                 ...
# 284  https://api.spotify.com/v1/tracks/6crfO56bDm0R...
# 285  https://api.spotify.com/v1/tracks/4l9hml2UCnxo...
# 286  https://api.spotify.com/v1/tracks/7Kqk5Epwqiuk...
# 287  https://api.spotify.com/v1/tracks/1sJnKCMOkGvc...
# 288  https://api.spotify.com/v1/tracks/4m6OC8u2rC6L...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/2Foa...      198293
# 1    https://api.spotify.com/v1/audio-analysis/6x9p...      143719
# 2    https://api.spotify.com/v1/audio-analysis/2FDT...      229133
# 3    https://api.spotify.com/v1/audio-analysis/5KI7...      231338
# 4    https://api.spotify.com/v1/audio-analysis/4yLy...      176835
# ..                                                 ...         ...
# 284  https://api.spotify.com/v1/audio-analysis/6crf...      149827
# 285  https://api.spotify.com/v1/audio-analysis/4l9h...      141133
# 286  https://api.spotify.com/v1/audio-analysis/7Kqk...      206653
# 287  https://api.spotify.com/v1/audio-analysis/1sJn...      123711
# 288  https://api.spotify.com/v1/audio-analysis/4m6O...      166760
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 284              4
# 285              4
# 286              4
# 287              4
# 288              4
#
# [289 rows x 22 columns]

# %%
drop_columns = ['Unnamed: 0', 'playlist', 'type', 'id', 'name', 'uri', 'track_href', 'analysis_url']

df_knn = df.drop(columns=drop_columns)

df_knn
# Out:
#     genre  danceability   energy  key  loudness  mode  speechiness  \
# 0     Rap         0.652  0.80600    5    -5.707     0       0.3020
# 1     Rap         0.818  0.51200    5    -9.056     0       0.0884
# 2     Rap         0.918  0.68100    1    -4.705     1       0.2010
# 3     Rap         0.701  0.65300    1    -4.695     1       0.1050
# 4     Rap         0.474  0.62100    7    -8.253     0       0.1030
# ..    ...           ...      ...  ...       ...   ...          ...
# 284   Old         0.580  0.05450    9   -14.594     0       0.0473
# 285   Old         0.438  0.00756    0   -26.440     0       0.0382
# 286   Old         0.677  0.26400    8    -9.111     1       0.0357
# 287   Old         0.840  0.17800   10   -11.133     1       0.0700
# 288   Old         0.501  0.04540    0   -18.783     1       0.0388
#
#      acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0          0.1220          0.000011    0.8420    0.779  159.947       198293
# 1          0.0963          0.037100    0.1100    0.153  131.974       143719
# 2          0.2630          0.000000    0.0615    0.706  139.057       229133
# 3          0.4790          0.000028    0.3060    0.505   82.984       231338
# 4          0.1870          0.000000    0.1600    0.396  114.314       176835
# ..            ...               ...       ...      ...      ...          ...
# 284        0.9630          0.000265    0.0967    0.177  123.341       149827
# 285        0.9410          0.006430    0.1090    0.277  133.320       141133
# 286        0.9040          0.006010    0.0825    0.438  120.974       206653
# 287        0.9730          0.000000    0.1130    0.529  114.412       123711
# 288        0.9380          0.000038    0.2000    0.255   99.783       166760
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 284               4
# 285               4
# 286               4
# 287               4
# 288               4
#
# [289 rows x 14 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(df_knn.drop('genre', axis = 1))
# Out:
# StandardScaler()

# %%
scaled_features = scaler.transform(df_knn.drop('genre', axis = 1))

# %%
df_feat = pd.DataFrame(scaled_features, columns = df_knn.columns[1:])
df_feat
# Out:
#      danceability    energy       key  loudness      mode  speechiness  \
# 0        0.298154  1.909276  0.014842  0.928430 -1.266335     1.970345
# 1        1.212476  0.673546  0.014842  0.446438 -1.266335    -0.122286
# 2        1.763272  1.383880 -1.128989  1.072639  0.789681     0.980852
# 3        0.568044  1.266192 -1.128989  1.074078  0.789681     0.040344
# 4       -0.682263  1.131691  0.586758  0.562007 -1.266335     0.020750
# ..            ...       ...       ...       ...       ...          ...
# 284     -0.098419 -1.249400  1.158674 -0.350597 -1.266335    -0.524941
# 285     -0.880550 -1.446696 -1.414947 -2.055487 -1.266335    -0.614093
# 286      0.435853 -0.368838  0.872716  0.438522  0.789681    -0.638586
# 287      1.333651 -0.730309  1.444631  0.147514  0.789681    -0.302550
# 288     -0.533548 -1.287648 -1.414947 -0.953483  0.789681    -0.608215
#
#      acousticness  instrumentalness  liveness   valence     tempo  \
# 0       -1.320475         -0.409573  6.097448  2.244916  1.484358
# 1       -1.392112         -0.277711 -0.472223 -1.014116  0.607365
# 2       -0.927450         -0.409612 -0.907508  1.864869  0.829427
# 3       -0.325370         -0.409511  1.286869  0.818438 -0.928541
# 4       -1.139293         -0.409612 -0.023475  0.250971  0.053699
# ..            ...               ...       ...       ...       ...
# 284      1.023737         -0.408669 -0.591590 -0.889170  0.336708
# 285      0.962414         -0.386751 -0.481198 -0.368557  0.649564
# 286      0.859280         -0.388244 -0.719034  0.469628  0.262499
# 287      1.051611         -0.409612 -0.445298  0.943385  0.056771
# 288      0.954052         -0.409478  0.335524 -0.483092 -0.401869
#
#      duration_ms  time_signature
# 0      -0.008676         0.32655
# 1      -0.770294         0.32655
# 2       0.421717         0.32655
# 3       0.452489         0.32655
# 4      -0.308137         0.32655
# ..           ...             ...
# 284    -0.685052         0.32655
# 285    -0.806383         0.32655
# 286     0.107993         0.32655
# 287    -1.049519         0.32655
# 288    -0.448741         0.32655
#
# [289 rows x 13 columns]

# %%
X = df_feat
y = df_knn['genre']

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=14)
X.shape
# Out:
# (289, 13)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2024)

# %%
forward_feature_selection = SequentialFeatureSelector(knn,
                                n_features_to_select=12, 
                                direction='forward', 
                                scoring='accuracy', 
                                cv=5, 
                                n_jobs=-1).fit(X,y)

# %%
forward_feature_selection.feature_names_in_
# Out:
# array(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'time_signature'], dtype=object)

# %%
forward_feature_select
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 cv_results = forward_feature_selection.cv_results_
#       3 cv_results_df = pd.DataFrame(cv_results)
#
# AttributeError: 'SequentialFeatureSelector' object has no attribute 'cv_results_'
